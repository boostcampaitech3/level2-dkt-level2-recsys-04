# %%
import pandas as pd
import numpy as np
import os
import random
import time
from datetime import datetime
from tqdm import tqdm 

import lightgbm as lgb
import xgboost as xgb
import catboost as cb
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

# %%
def custom_train_test_split(df, ratio=0.7, split=True): # train과 test 데이터셋은 사용자 별로 묶어서 분리를 해주어야함
    random.seed(42)
    
    users = list(zip(df['userID'].value_counts().index, df['userID'].value_counts()))
    random.shuffle(users)
    
    max_train_data_len = ratio * len(df)
    sum_of_train_data = 0
    
    user_ids = []

    for user_id, count in users:
        sum_of_train_data += count
        if max_train_data_len < sum_of_train_data:
            break
        user_ids.append(user_id)

    train = df[df['userID'].isin(user_ids)]
    test = df[df['userID'].isin(user_ids) == False]

    #test데이터셋은 각 유저의 마지막 interaction만 추출
    test = test[test['userID'] != test['userID'].shift(-1)]
    return train, test

# %%
data_dir = '/opt/ml/input/DKT/data'

own_df = pd.read_csv(os.path.join(data_dir, 'own_df.csv'))

# %%
# category column type casting
cate = sum([['testId', 'assessmentItemID', 'KnowledgeTag', 'character_outlier_mean', 'character_outlier_median', 'character_detail_outlier_mean'],
            ['character_detail_outlier_median', 'week_number', 'mday', 'hour', 'difficulty', 'KnowledgeTag_cnt', 'assessmentItemID_cnt', 'month', 'is_last', 'tag_test'],
            [f'past_OX_{i}' for i in range(1, 6)],
            [f'past_KnowledgeTag_{i}' for i in range(1, 6)],
            [f'past_testid_{i}' for i in range(1, 11)],
            [f'past_testid_{i}_tag_{j}' for i in range(1, 11) for j in range(1, 4)],
            [f'past_character_mean_{i}' for i in range(1, 6)],
            [f'past_character_median_{i}' for i in range(1, 6)],
            [f'past_character_detail_mean_{i}' for i in range(1, 6)],
            [f'past_character_detail_median_{i}' for i in range(1, 6)]
           ], [])

for c in cate:
    own_df[c] = own_df[c].astype('category')

# %%
# inference에 사용하는 data와, train에 사용하는 data 분류
ttt = own_df[own_df['answerCode'] == -1].reset_index(drop=True) # inference에 사용
dfdf = own_df[own_df['answerCode'] != -1].reset_index(drop=True) # train에 사용

# %%
# 유저별 분리
train, test = custom_train_test_split(dfdf, ratio=0.7)

# X, y 값 분리
y_train = train['answerCode']
train = train.drop(['answerCode'], axis=1)

y_test = test['answerCode']
test = test.drop(['answerCode'], axis=1)

# %%
past_ox =4
past_testid = 5

FEATS = sum([['assessmentItemID',
        'testId',
        'KnowledgeTag',
        'difficulty',
        'testId_mean',
        'normalize_score',
        'assessmentItemID_mean',
        'character_outlier_median',
        'character_outlier_mean',
        'character_detail_outlier_median',
        'character_detail_outlier_mean',
        'week_number',
        'testId_own_mean',
        'mday',
        'hour',
        'tag_test',
        'duration_outlier_median',
        'duration_outlier_mean',
        ],
        [f'past_OX_{i}' for i in range(1, 1 + past_ox)],
        [f'past_KnowledgeTag_{i}' for i in range(1, 1 + past_ox)],
        [f'past_character_median_{i}' for i in range(1, 1 + past_ox)],
        [f'past_character_mean_{i}' for i in range(1, 1 + past_ox)],
        [f'past_character_detail_median_{i}' for i in range(1, 1 + past_ox)],
        [f'past_character_detail_mean_{i}' for i in range(1, 1 + past_ox)],
        [f'past_duration_median_{i}' for i in range(1, 1 + past_ox)],
        [f'past_duration_mean_{i}' for i in range(1, 1 + past_ox)],
        [f'past_testid_{i}' for i in range(1, 1 + past_testid)],
        [f'past_testid_{i}_mean' for i in range(1, 1 + past_testid)],
        # [f'past_testid_{i}_timelap' for i in range(1, 1 + past_testid)],
        [f'past_testid_{i}_own' for i in range(1, 1 + past_testid)],
        [f'past_testid_{i}_normalize_score' for i in range(1, 1 + past_testid)],
        [f'past_testid_{i}_tag_{j + 1}' for i in range(1, 1 + past_testid) for j in range(2)]
    ],
    [])

# %% [markdown]
# #### LGBM

# %%
lgb_train = lgb.Dataset(train[FEATS], y_train)
lgb_test = lgb.Dataset(test[FEATS], y_test)

params = {'learning_rate': 0.01,
            'max_depth':8,
            'boosting': 'gbdt',
            'objective': 'binary',
            'metric': 'auc',
#           'is_training_metric': True,
            'num_leaves': 64,
            'feature_fraction': 1,
            'bagging_fraction': 1,
            'bagging_freq': 5,
            'seed':42,
            'device':'cpu'
            # 'device':'gpu',
            # 'gpu_device_id':0
            }

model = lgb.train(
                    params, 
                    lgb_train,
                    valid_sets=[lgb_train, lgb_test],
                    verbose_eval=-1,
                    num_boost_round=20000,
                    early_stopping_rounds=100
                )

preds = model.predict(test[FEATS])
acc = accuracy_score(y_test, np.where(preds >= 0.5, 1, 0))
auc = roc_auc_score(y_test, preds)

print(f'VALID AUC : {auc} ACC : {acc}\n')
# Out:
# /opt/ml/input/DKT/.venv/lib/python3.8/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/ml/input/DKT/.venv/lib/python3.8/site-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [LightGBM] [Info] Number of positive: 163649, number of negative: 128081
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031857 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 22152
# [LightGBM] [Info] Number of data points in the train set: 291730, number of used features: 80
# /opt/ml/input/DKT/.venv/lib/python3.8/site-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /opt/ml/input/DKT/.venv/lib/python3.8/site-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.560960 -> initscore=0.245061
# [LightGBM] [Info] Start training from score 0.245061
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [540]	training's auc: 0.884893	valid_1's auc: 0.842022
# VALID AUC : 0.8420224403927069 ACC : 0.7628635346756152

# %% [markdown]
# #### XGBoost

# %%
xgb_train = xgb.DMatrix(train[FEATS], y_train, enable_categorical=True)
xgb_test = xgb.DMatrix(test[FEATS], y_test, enable_categorical=True)

params = {'learning_rate': 0.01,
            'max_depth':8,
            'eta' : 0.1,
            'objective': 'binary:logistic',
            'eval_metric': 'auc',
#           'is_training_metric': True,
            'feature_fraction': 1,
            'seed':42,
            'gpu_id':0
            }

model = xgb.train(
                    params, 
                    xgb_train,
                    evals = [(xgb_train, 'train'), (xgb_test,'eval')],
                    num_boost_round=500,
                    early_stopping_rounds=100
                )

preds = model.predict(xgb_test)
acc = accuracy_score(y_test, np.where(preds >= 0.5, 1, 0))
auc = roc_auc_score(y_test, preds)

print(f'VALID AUC : {auc} ACC : {acc}\n')
# Out:
# [19:09:51] WARNING: ../src/learner.cc:627:
# Parameters: { "feature_fraction" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-auc:0.83473	eval-auc:0.83483
# [1]	train-auc:0.83538	eval-auc:0.83558
# [2]	train-auc:0.83573	eval-auc:0.83577
# [3]	train-auc:0.83646	eval-auc:0.83728
# [4]	train-auc:0.83671	eval-auc:0.83779
# [5]	train-auc:0.83680	eval-auc:0.83781
# [6]	train-auc:0.83702	eval-auc:0.83795
# [7]	train-auc:0.83732	eval-auc:0.83845
# [8]	train-auc:0.83749	eval-auc:0.83864
# [9]	train-auc:0.83772	eval-auc:0.83901
# [10]	train-auc:0.83793	eval-auc:0.83919
# [11]	train-auc:0.83809	eval-auc:0.83947
# [12]	train-auc:0.83819	eval-auc:0.83958
# [13]	train-auc:0.83857	eval-auc:0.84000
# [14]	train-auc:0.83883	eval-auc:0.84031
# [15]	train-auc:0.83901	eval-auc:0.84021
# [16]	train-auc:0.83917	eval-auc:0.84041
# [17]	train-auc:0.83932	eval-auc:0.84058
# [18]	train-auc:0.83949	eval-auc:0.84050
# [19]	train-auc:0.83962	eval-auc:0.84071
# [20]	train-auc:0.83974	eval-auc:0.84072
# [21]	train-auc:0.83993	eval-auc:0.84093
# [22]	train-auc:0.84006	eval-auc:0.84084
# [23]	train-auc:0.84017	eval-auc:0.84096
# [24]	train-auc:0.84029	eval-auc:0.84105
# [25]	train-auc:0.84037	eval-auc:0.84102
# [26]	train-auc:0.84047	eval-auc:0.84092
# [27]	train-auc:0.84057	eval-auc:0.84095
# [28]	train-auc:0.84064	eval-auc:0.84101
# [29]	train-auc:0.84074	eval-auc:0.84118
# [30]	train-auc:0.84083	eval-auc:0.84111
# [31]	train-auc:0.84093	eval-auc:0.84113
# [32]	train-auc:0.84101	eval-auc:0.84115
# [33]	train-auc:0.84108	eval-auc:0.84126
# [34]	train-auc:0.84115	eval-auc:0.84127
# [35]	train-auc:0.84122	eval-auc:0.84133
# [36]	train-auc:0.84132	eval-auc:0.84133
# [37]	train-auc:0.84138	eval-auc:0.84123
# [38]	train-auc:0.84146	eval-auc:0.84118
# [39]	train-auc:0.84154	eval-auc:0.84110
# [40]	train-auc:0.84161	eval-auc:0.84104
# [41]	train-auc:0.84168	eval-auc:0.84110
# [42]	train-auc:0.84174	eval-auc:0.84110
# [43]	train-auc:0.84179	eval-auc:0.84116
# [44]	train-auc:0.84187	eval-auc:0.84111
# [45]	train-auc:0.84194	eval-auc:0.84122
# [46]	train-auc:0.84200	eval-auc:0.84117
# [47]	train-auc:0.84205	eval-auc:0.84119
# [48]	train-auc:0.84211	eval-auc:0.84114
# [49]	train-auc:0.84216	eval-auc:0.84124
# [50]	train-auc:0.84225	eval-auc:0.84121
# [51]	train-auc:0.84230	eval-auc:0.84123
# [52]	train-auc:0.84235	eval-auc:0.84125
# [53]	train-auc:0.84242	eval-auc:0.84128
# [54]	train-auc:0.84246	eval-auc:0.84129
# [55]	train-auc:0.84252	eval-auc:0.84128
# [56]	train-auc:0.84257	eval-auc:0.84124
# [57]	train-auc:0.84263	eval-auc:0.84128
# [58]	train-auc:0.84269	eval-auc:0.84121
# [59]	train-auc:0.84274	eval-auc:0.84127
# [60]	train-auc:0.84279	eval-auc:0.84122
# [61]	train-auc:0.84284	eval-auc:0.84119
# [62]	train-auc:0.84290	eval-auc:0.84133
# [63]	train-auc:0.84296	eval-auc:0.84139
# [64]	train-auc:0.84301	eval-auc:0.84152
# [65]	train-auc:0.84306	eval-auc:0.84163
# [66]	train-auc:0.84312	eval-auc:0.84169
# [67]	train-auc:0.84317	eval-auc:0.84174
# [68]	train-auc:0.84321	eval-auc:0.84178
# [69]	train-auc:0.84328	eval-auc:0.84175
# [70]	train-auc:0.84332	eval-auc:0.84186
# [71]	train-auc:0.84337	eval-auc:0.84189
# [72]	train-auc:0.84342	eval-auc:0.84193
# [73]	train-auc:0.84347	eval-auc:0.84198
# [74]	train-auc:0.84351	eval-auc:0.84201
# [75]	train-auc:0.84357	eval-auc:0.84216
# [76]	train-auc:0.84362	eval-auc:0.84217
# [77]	train-auc:0.84366	eval-auc:0.84217
# [78]	train-auc:0.84371	eval-auc:0.84225
# [79]	train-auc:0.84377	eval-auc:0.84224
# [80]	train-auc:0.84383	eval-auc:0.84223
# [81]	train-auc:0.84389	eval-auc:0.84219
# [82]	train-auc:0.84395	eval-auc:0.84220
# [83]	train-auc:0.84400	eval-auc:0.84230
# [84]	train-auc:0.84405	eval-auc:0.84232
# [85]	train-auc:0.84411	eval-auc:0.84238
# [86]	train-auc:0.84416	eval-auc:0.84231
# [87]	train-auc:0.84422	eval-auc:0.84253
# [88]	train-auc:0.84427	eval-auc:0.84257
# [89]	train-auc:0.84431	eval-auc:0.84262
# [90]	train-auc:0.84436	eval-auc:0.84261
# [91]	train-auc:0.84442	eval-auc:0.84265
# [92]	train-auc:0.84446	eval-auc:0.84268
# [93]	train-auc:0.84451	eval-auc:0.84275
# [94]	train-auc:0.84456	eval-auc:0.84271
# [95]	train-auc:0.84460	eval-auc:0.84274
# [96]	train-auc:0.84465	eval-auc:0.84273
# [97]	train-auc:0.84470	eval-auc:0.84271
# [98]	train-auc:0.84475	eval-auc:0.84275
# [99]	train-auc:0.84481	eval-auc:0.84278
# [100]	train-auc:0.84486	eval-auc:0.84281
# [101]	train-auc:0.84491	eval-auc:0.84281
# [102]	train-auc:0.84498	eval-auc:0.84282
# [103]	train-auc:0.84502	eval-auc:0.84280
# [104]	train-auc:0.84507	eval-auc:0.84282
# [105]	train-auc:0.84512	eval-auc:0.84281
# [106]	train-auc:0.84516	eval-auc:0.84281
# [107]	train-auc:0.84521	eval-auc:0.84284
# [108]	train-auc:0.84527	eval-auc:0.84280
# [109]	train-auc:0.84532	eval-auc:0.84281
# [110]	train-auc:0.84535	eval-auc:0.84282
# [111]	train-auc:0.84539	eval-auc:0.84284
# [112]	train-auc:0.84544	eval-auc:0.84280
# [113]	train-auc:0.84549	eval-auc:0.84284
# [114]	train-auc:0.84553	eval-auc:0.84283
# [115]	train-auc:0.84557	eval-auc:0.84280
# [116]	train-auc:0.84561	eval-auc:0.84280
# [117]	train-auc:0.84566	eval-auc:0.84284
# [118]	train-auc:0.84571	eval-auc:0.84288
# [119]	train-auc:0.84576	eval-auc:0.84291
# [120]	train-auc:0.84581	eval-auc:0.84294
# [121]	train-auc:0.84586	eval-auc:0.84291
# [122]	train-auc:0.84591	eval-auc:0.84287
# [123]	train-auc:0.84596	eval-auc:0.84287
# [124]	train-auc:0.84601	eval-auc:0.84292
# [125]	train-auc:0.84607	eval-auc:0.84293
# [126]	train-auc:0.84613	eval-auc:0.84296
# [127]	train-auc:0.84619	eval-auc:0.84298
# [128]	train-auc:0.84625	eval-auc:0.84301
# [129]	train-auc:0.84631	eval-auc:0.84304
# [130]	train-auc:0.84637	eval-auc:0.84307
# [131]	train-auc:0.84642	eval-auc:0.84309
# [132]	train-auc:0.84648	eval-auc:0.84310
# [133]	train-auc:0.84653	eval-auc:0.84313
# [134]	train-auc:0.84659	eval-auc:0.84318
# [135]	train-auc:0.84664	eval-auc:0.84319
# [136]	train-auc:0.84670	eval-auc:0.84324
# [137]	train-auc:0.84674	eval-auc:0.84322
# [138]	train-auc:0.84680	eval-auc:0.84324
# [139]	train-auc:0.84685	eval-auc:0.84330
# [140]	train-auc:0.84691	eval-auc:0.84332
# [141]	train-auc:0.84695	eval-auc:0.84336
# [142]	train-auc:0.84701	eval-auc:0.84335
# [143]	train-auc:0.84706	eval-auc:0.84328
# [144]	train-auc:0.84710	eval-auc:0.84325
# [145]	train-auc:0.84714	eval-auc:0.84330
# [146]	train-auc:0.84719	eval-auc:0.84333
# [147]	train-auc:0.84724	eval-auc:0.84328
# [148]	train-auc:0.84729	eval-auc:0.84330
# [149]	train-auc:0.84734	eval-auc:0.84334
# [150]	train-auc:0.84738	eval-auc:0.84333
# [151]	train-auc:0.84743	eval-auc:0.84327
# [152]	train-auc:0.84747	eval-auc:0.84327
# [153]	train-auc:0.84753	eval-auc:0.84330
# [154]	train-auc:0.84757	eval-auc:0.84331
# [155]	train-auc:0.84762	eval-auc:0.84332
# [156]	train-auc:0.84767	eval-auc:0.84331
# [157]	train-auc:0.84771	eval-auc:0.84327
# [158]	train-auc:0.84776	eval-auc:0.84328
# [159]	train-auc:0.84781	eval-auc:0.84328
# [160]	train-auc:0.84785	eval-auc:0.84327
# [161]	train-auc:0.84789	eval-auc:0.84327
# [162]	train-auc:0.84794	eval-auc:0.84324
# [163]	train-auc:0.84799	eval-auc:0.84323
# [164]	train-auc:0.84803	eval-auc:0.84318
# [165]	train-auc:0.84807	eval-auc:0.84325
# [166]	train-auc:0.84811	eval-auc:0.84324
# [167]	train-auc:0.84817	eval-auc:0.84329
# [168]	train-auc:0.84822	eval-auc:0.84332
# [169]	train-auc:0.84827	eval-auc:0.84332
# [170]	train-auc:0.84833	eval-auc:0.84338
# [171]	train-auc:0.84838	eval-auc:0.84338
# [172]	train-auc:0.84843	eval-auc:0.84337
# [173]	train-auc:0.84848	eval-auc:0.84341
# [174]	train-auc:0.84853	eval-auc:0.84341
# [175]	train-auc:0.84857	eval-auc:0.84346
# [176]	train-auc:0.84862	eval-auc:0.84349
# [177]	train-auc:0.84867	eval-auc:0.84354
# [178]	train-auc:0.84873	eval-auc:0.84359
# [179]	train-auc:0.84878	eval-auc:0.84357
# [180]	train-auc:0.84882	eval-auc:0.84357
# [181]	train-auc:0.84887	eval-auc:0.84359
# [182]	train-auc:0.84893	eval-auc:0.84366
# [183]	train-auc:0.84897	eval-auc:0.84365
# [184]	train-auc:0.84903	eval-auc:0.84372
# [185]	train-auc:0.84908	eval-auc:0.84370
# [186]	train-auc:0.84914	eval-auc:0.84378
# [187]	train-auc:0.84918	eval-auc:0.84386
# [188]	train-auc:0.84923	eval-auc:0.84398
# [189]	train-auc:0.84928	eval-auc:0.84390
# [190]	train-auc:0.84933	eval-auc:0.84392
# [191]	train-auc:0.84938	eval-auc:0.84397
# [192]	train-auc:0.84943	eval-auc:0.84405
# [193]	train-auc:0.84948	eval-auc:0.84408
# [194]	train-auc:0.84953	eval-auc:0.84413
# [195]	train-auc:0.84960	eval-auc:0.84420
# [196]	train-auc:0.84966	eval-auc:0.84423
# [197]	train-auc:0.84971	eval-auc:0.84426
# [198]	train-auc:0.84977	eval-auc:0.84431
# [199]	train-auc:0.84982	eval-auc:0.84439
# [200]	train-auc:0.84987	eval-auc:0.84447
# [201]	train-auc:0.84993	eval-auc:0.84450
# [202]	train-auc:0.84997	eval-auc:0.84449
# [203]	train-auc:0.85003	eval-auc:0.84458
# [204]	train-auc:0.85008	eval-auc:0.84460
# [205]	train-auc:0.85014	eval-auc:0.84459
# [206]	train-auc:0.85020	eval-auc:0.84460
# [207]	train-auc:0.85026	eval-auc:0.84460
# [208]	train-auc:0.85030	eval-auc:0.84461
# [209]	train-auc:0.85036	eval-auc:0.84464
# [210]	train-auc:0.85041	eval-auc:0.84465
# [211]	train-auc:0.85047	eval-auc:0.84470
# [212]	train-auc:0.85051	eval-auc:0.84472
# [213]	train-auc:0.85056	eval-auc:0.84470
# [214]	train-auc:0.85062	eval-auc:0.84477
# [215]	train-auc:0.85067	eval-auc:0.84483
# [216]	train-auc:0.85071	eval-auc:0.84482
# [217]	train-auc:0.85077	eval-auc:0.84486
# [218]	train-auc:0.85082	eval-auc:0.84485
# [219]	train-auc:0.85087	eval-auc:0.84487
# [220]	train-auc:0.85092	eval-auc:0.84485
# [221]	train-auc:0.85098	eval-auc:0.84487
# [222]	train-auc:0.85102	eval-auc:0.84489
# [223]	train-auc:0.85107	eval-auc:0.84489
# [224]	train-auc:0.85112	eval-auc:0.84494
# [225]	train-auc:0.85117	eval-auc:0.84497
# [226]	train-auc:0.85123	eval-auc:0.84492
# [227]	train-auc:0.85129	eval-auc:0.84492
# [228]	train-auc:0.85135	eval-auc:0.84494
# [229]	train-auc:0.85140	eval-auc:0.84498
# [230]	train-auc:0.85145	eval-auc:0.84498
# [231]	train-auc:0.85151	eval-auc:0.84504
# [232]	train-auc:0.85156	eval-auc:0.84509
# [233]	train-auc:0.85161	eval-auc:0.84512
# [234]	train-auc:0.85166	eval-auc:0.84514
# [235]	train-auc:0.85171	eval-auc:0.84514
# [236]	train-auc:0.85177	eval-auc:0.84519
# [237]	train-auc:0.85182	eval-auc:0.84522
# [238]	train-auc:0.85187	eval-auc:0.84528
# [239]	train-auc:0.85192	eval-auc:0.84530
# [240]	train-auc:0.85198	eval-auc:0.84530
# [241]	train-auc:0.85203	eval-auc:0.84538
# [242]	train-auc:0.85209	eval-auc:0.84538
# [243]	train-auc:0.85214	eval-auc:0.84544
# [244]	train-auc:0.85218	eval-auc:0.84543
# [245]	train-auc:0.85224	eval-auc:0.84544
# [246]	train-auc:0.85229	eval-auc:0.84555
# [247]	train-auc:0.85234	eval-auc:0.84555
# [248]	train-auc:0.85239	eval-auc:0.84556
# [249]	train-auc:0.85245	eval-auc:0.84556
# [250]	train-auc:0.85250	eval-auc:0.84559
# [251]	train-auc:0.85255	eval-auc:0.84559
# [252]	train-auc:0.85260	eval-auc:0.84562
# [253]	train-auc:0.85265	eval-auc:0.84569
# [254]	train-auc:0.85270	eval-auc:0.84573
# [255]	train-auc:0.85275	eval-auc:0.84578
# [256]	train-auc:0.85280	eval-auc:0.84577
# [257]	train-auc:0.85285	eval-auc:0.84575
# [258]	train-auc:0.85290	eval-auc:0.84575
# [259]	train-auc:0.85295	eval-auc:0.84578
# [260]	train-auc:0.85300	eval-auc:0.84581
# [261]	train-auc:0.85304	eval-auc:0.84583
# [262]	train-auc:0.85310	eval-auc:0.84581
# [263]	train-auc:0.85315	eval-auc:0.84588
# [264]	train-auc:0.85320	eval-auc:0.84587
# [265]	train-auc:0.85326	eval-auc:0.84584
# [266]	train-auc:0.85330	eval-auc:0.84586
# [267]	train-auc:0.85335	eval-auc:0.84587
# [268]	train-auc:0.85340	eval-auc:0.84584
# [269]	train-auc:0.85345	eval-auc:0.84582
# [270]	train-auc:0.85350	eval-auc:0.84582
# [271]	train-auc:0.85355	eval-auc:0.84583
# [272]	train-auc:0.85359	eval-auc:0.84585
# [273]	train-auc:0.85364	eval-auc:0.84588
# [274]	train-auc:0.85369	eval-auc:0.84588
# [275]	train-auc:0.85374	eval-auc:0.84586
# [276]	train-auc:0.85378	eval-auc:0.84589
# [277]	train-auc:0.85383	eval-auc:0.84584
# [278]	train-auc:0.85388	eval-auc:0.84585
# [279]	train-auc:0.85393	eval-auc:0.84583
# [280]	train-auc:0.85397	eval-auc:0.84580
# [281]	train-auc:0.85403	eval-auc:0.84579
# [282]	train-auc:0.85407	eval-auc:0.84580
# [283]	train-auc:0.85411	eval-auc:0.84586
# [284]	train-auc:0.85416	eval-auc:0.84588
# [285]	train-auc:0.85421	eval-auc:0.84585
# [286]	train-auc:0.85426	eval-auc:0.84586
# [287]	train-auc:0.85430	eval-auc:0.84586
# [288]	train-auc:0.85435	eval-auc:0.84591
# [289]	train-auc:0.85440	eval-auc:0.84587
# [290]	train-auc:0.85444	eval-auc:0.84589
# [291]	train-auc:0.85449	eval-auc:0.84585
# [292]	train-auc:0.85454	eval-auc:0.84585
# [293]	train-auc:0.85459	eval-auc:0.84589
# [294]	train-auc:0.85464	eval-auc:0.84586
# [295]	train-auc:0.85468	eval-auc:0.84581
# [296]	train-auc:0.85473	eval-auc:0.84587
# [297]	train-auc:0.85477	eval-auc:0.84586
# [298]	train-auc:0.85482	eval-auc:0.84583
# [299]	train-auc:0.85487	eval-auc:0.84587
# [300]	train-auc:0.85492	eval-auc:0.84591
# [301]	train-auc:0.85496	eval-auc:0.84589
# [302]	train-auc:0.85501	eval-auc:0.84588
# [303]	train-auc:0.85506	eval-auc:0.84593
# [304]	train-auc:0.85510	eval-auc:0.84594
# [305]	train-auc:0.85515	eval-auc:0.84594
# [306]	train-auc:0.85519	eval-auc:0.84594
# [307]	train-auc:0.85524	eval-auc:0.84598
# [308]	train-auc:0.85529	eval-auc:0.84601
# [309]	train-auc:0.85533	eval-auc:0.84601
# [310]	train-auc:0.85538	eval-auc:0.84606
# [311]	train-auc:0.85542	eval-auc:0.84601
# [312]	train-auc:0.85547	eval-auc:0.84599
# [313]	train-auc:0.85552	eval-auc:0.84601
# [314]	train-auc:0.85556	eval-auc:0.84603
# [315]	train-auc:0.85561	eval-auc:0.84601
# [316]	train-auc:0.85566	eval-auc:0.84604
# [317]	train-auc:0.85571	eval-auc:0.84605
# [318]	train-auc:0.85575	eval-auc:0.84605
# [319]	train-auc:0.85581	eval-auc:0.84605
# [320]	train-auc:0.85585	eval-auc:0.84607
# [321]	train-auc:0.85590	eval-auc:0.84608
# [322]	train-auc:0.85594	eval-auc:0.84608
# [323]	train-auc:0.85599	eval-auc:0.84608
# [324]	train-auc:0.85603	eval-auc:0.84609
# [325]	train-auc:0.85608	eval-auc:0.84610
# [326]	train-auc:0.85612	eval-auc:0.84610
# [327]	train-auc:0.85617	eval-auc:0.84605
# [328]	train-auc:0.85621	eval-auc:0.84602
# [329]	train-auc:0.85626	eval-auc:0.84598
# [330]	train-auc:0.85630	eval-auc:0.84600
# [331]	train-auc:0.85635	eval-auc:0.84601
# [332]	train-auc:0.85640	eval-auc:0.84600
# [333]	train-auc:0.85644	eval-auc:0.84601
# [334]	train-auc:0.85649	eval-auc:0.84600
# [335]	train-auc:0.85653	eval-auc:0.84601
# [336]	train-auc:0.85657	eval-auc:0.84595
# [337]	train-auc:0.85662	eval-auc:0.84597
# [338]	train-auc:0.85666	eval-auc:0.84595
# [339]	train-auc:0.85670	eval-auc:0.84593
# [340]	train-auc:0.85674	eval-auc:0.84590
# [341]	train-auc:0.85679	eval-auc:0.84594
# [342]	train-auc:0.85683	eval-auc:0.84596
# [343]	train-auc:0.85688	eval-auc:0.84594
# [344]	train-auc:0.85693	eval-auc:0.84594
# [345]	train-auc:0.85697	eval-auc:0.84593
# [346]	train-auc:0.85701	eval-auc:0.84593
# [347]	train-auc:0.85706	eval-auc:0.84590
# [348]	train-auc:0.85710	eval-auc:0.84589
# [349]	train-auc:0.85714	eval-auc:0.84586
# [350]	train-auc:0.85718	eval-auc:0.84587
# [351]	train-auc:0.85722	eval-auc:0.84578
# [352]	train-auc:0.85727	eval-auc:0.84581
# [353]	train-auc:0.85731	eval-auc:0.84579
# [354]	train-auc:0.85735	eval-auc:0.84582
# [355]	train-auc:0.85740	eval-auc:0.84577
# [356]	train-auc:0.85744	eval-auc:0.84578
# [357]	train-auc:0.85749	eval-auc:0.84581
# [358]	train-auc:0.85753	eval-auc:0.84579
# [359]	train-auc:0.85758	eval-auc:0.84580
# [360]	train-auc:0.85762	eval-auc:0.84580
# [361]	train-auc:0.85766	eval-auc:0.84581
# [362]	train-auc:0.85770	eval-auc:0.84580
# [363]	train-auc:0.85774	eval-auc:0.84578
# [364]	train-auc:0.85779	eval-auc:0.84581
# [365]	train-auc:0.85784	eval-auc:0.84577
# [366]	train-auc:0.85788	eval-auc:0.84574
# [367]	train-auc:0.85792	eval-auc:0.84576
# [368]	train-auc:0.85797	eval-auc:0.84580
# [369]	train-auc:0.85801	eval-auc:0.84580
# [370]	train-auc:0.85805	eval-auc:0.84577
# [371]	train-auc:0.85809	eval-auc:0.84578
# [372]	train-auc:0.85814	eval-auc:0.84571
# [373]	train-auc:0.85818	eval-auc:0.84571
# [374]	train-auc:0.85823	eval-auc:0.84574
# [375]	train-auc:0.85827	eval-auc:0.84575
# [376]	train-auc:0.85831	eval-auc:0.84578
# [377]	train-auc:0.85835	eval-auc:0.84580
# [378]	train-auc:0.85840	eval-auc:0.84580
# [379]	train-auc:0.85844	eval-auc:0.84584
# [380]	train-auc:0.85848	eval-auc:0.84584
# [381]	train-auc:0.85852	eval-auc:0.84582
# [382]	train-auc:0.85856	eval-auc:0.84580
# [383]	train-auc:0.85861	eval-auc:0.84579
# [384]	train-auc:0.85864	eval-auc:0.84580
# [385]	train-auc:0.85868	eval-auc:0.84578
# [386]	train-auc:0.85872	eval-auc:0.84578
# [387]	train-auc:0.85876	eval-auc:0.84578
# [388]	train-auc:0.85880	eval-auc:0.84582
# [389]	train-auc:0.85885	eval-auc:0.84579
# [390]	train-auc:0.85889	eval-auc:0.84582
# [391]	train-auc:0.85893	eval-auc:0.84584
# [392]	train-auc:0.85897	eval-auc:0.84585
# [393]	train-auc:0.85902	eval-auc:0.84585
# [394]	train-auc:0.85906	eval-auc:0.84582
# [395]	train-auc:0.85910	eval-auc:0.84585
# [396]	train-auc:0.85914	eval-auc:0.84586
# [397]	train-auc:0.85919	eval-auc:0.84586
# [398]	train-auc:0.85922	eval-auc:0.84584
# [399]	train-auc:0.85927	eval-auc:0.84586
# [400]	train-auc:0.85930	eval-auc:0.84585
# [401]	train-auc:0.85934	eval-auc:0.84582
# [402]	train-auc:0.85939	eval-auc:0.84581
# [403]	train-auc:0.85942	eval-auc:0.84580
# [404]	train-auc:0.85947	eval-auc:0.84580
# [405]	train-auc:0.85951	eval-auc:0.84582
# [406]	train-auc:0.85954	eval-auc:0.84581
# [407]	train-auc:0.85958	eval-auc:0.84580
# [408]	train-auc:0.85962	eval-auc:0.84578
# [409]	train-auc:0.85966	eval-auc:0.84578
# [410]	train-auc:0.85970	eval-auc:0.84581
# [411]	train-auc:0.85975	eval-auc:0.84581
# [412]	train-auc:0.85979	eval-auc:0.84576
# [413]	train-auc:0.85983	eval-auc:0.84577
# [414]	train-auc:0.85986	eval-auc:0.84578
# [415]	train-auc:0.85991	eval-auc:0.84580
# [416]	train-auc:0.85996	eval-auc:0.84580
# [417]	train-auc:0.85999	eval-auc:0.84577
# [418]	train-auc:0.86003	eval-auc:0.84576
# [419]	train-auc:0.86007	eval-auc:0.84572
# [420]	train-auc:0.86011	eval-auc:0.84572
# [421]	train-auc:0.86015	eval-auc:0.84573
# [422]	train-auc:0.86019	eval-auc:0.84576
# [423]	train-auc:0.86023	eval-auc:0.84574
# [424]	train-auc:0.86028	eval-auc:0.84577
# [425]	train-auc:0.86033	eval-auc:0.84578
# [426]	train-auc:0.86037	eval-auc:0.84577
# VALID AUC : 0.8457679823682629 ACC : 0.7655480984340045

# %% [markdown]
# #### Catboost

# %%
from pandas.api.types import is_numeric_dtype

def get_categorical_indicies(X):
    cats = []
    for col in X.columns:
        if is_numeric_dtype(X[col]):
            pass
        else:
            cats.append(col)
    cat_indicies = []
    for col in cats:
        cat_indicies.append(X.columns.get_loc(col))
    return cat_indicies

# %%
train_categorical_indicies = get_categorical_indicies(train[FEATS])
test_categorical_indicies = get_categorical_indicies(test[FEATS])

cb_train = cb.Pool(train[FEATS],y_train, cat_features=train_categorical_indicies)
cb_test = cb.Pool(test[FEATS],y_test, cat_features=test_categorical_indicies)

params = {'learning_rate': 0.01,
            'depth':8,
            'objective': 'CrossEntropy',
            'eval_metric': 'AUC',
#           'is_training_metric': True,
            # 'seed':42,
            'task_type':"GPU",
            # 'devices':0
            }

model = cb.train(
                    params=params, 
                    dtrain=cb_train,
                    eval_set = cb_test,
                    num_boost_round=500,
                    early_stopping_rounds=100
                )

preds = model.predict(cb_test)
acc = accuracy_score(y_test, np.where(preds >= 0.5, 1, 0))
auc = roc_auc_score(y_test, preds)

print(f'VALID AUC : {auc} ACC : {acc}\n')
# Out:
# 0:	test: 0.8112859	best: 0.8112859 (0)	total: 155ms	remaining: 1m 17s
# 1:	test: 0.8155336	best: 0.8155336 (1)	total: 301ms	remaining: 1m 15s
# 2:	test: 0.8174759	best: 0.8174759 (2)	total: 445ms	remaining: 1m 13s
# 3:	test: 0.8173320	best: 0.8174759 (2)	total: 573ms	remaining: 1m 11s
# 4:	test: 0.8186384	best: 0.8186384 (4)	total: 711ms	remaining: 1m 10s
# 5:	test: 0.8191797	best: 0.8191797 (5)	total: 850ms	remaining: 1m 9s
# 6:	test: 0.8202829	best: 0.8202829 (6)	total: 987ms	remaining: 1m 9s
# 7:	test: 0.8216594	best: 0.8216594 (7)	total: 1.12s	remaining: 1m 9s
# 8:	test: 0.8220593	best: 0.8220593 (8)	total: 1.25s	remaining: 1m 8s
# 9:	test: 0.8228203	best: 0.8228203 (9)	total: 1.39s	remaining: 1m 7s
# 10:	test: 0.8224869	best: 0.8228203 (9)	total: 1.51s	remaining: 1m 7s
# 11:	test: 0.8221058	best: 0.8228203 (9)	total: 1.65s	remaining: 1m 7s
# 12:	test: 0.8226756	best: 0.8228203 (9)	total: 1.79s	remaining: 1m 7s
# 13:	test: 0.8232919	best: 0.8232919 (13)	total: 1.93s	remaining: 1m 7s
# 14:	test: 0.8237423	best: 0.8237423 (14)	total: 2.07s	remaining: 1m 6s
# 15:	test: 0.8233533	best: 0.8237423 (14)	total: 2.18s	remaining: 1m 6s
# 16:	test: 0.8235584	best: 0.8237423 (14)	total: 2.32s	remaining: 1m 5s
# 17:	test: 0.8233080	best: 0.8237423 (14)	total: 2.46s	remaining: 1m 5s
# 18:	test: 0.8240040	best: 0.8240040 (18)	total: 2.6s	remaining: 1m 5s
# 19:	test: 0.8241811	best: 0.8241811 (19)	total: 2.74s	remaining: 1m 5s
# 20:	test: 0.8244280	best: 0.8244280 (20)	total: 2.88s	remaining: 1m 5s
# 21:	test: 0.8245634	best: 0.8245634 (21)	total: 3.01s	remaining: 1m 5s
# 22:	test: 0.8246993	best: 0.8246993 (22)	total: 3.15s	remaining: 1m 5s
# 23:	test: 0.8245851	best: 0.8246993 (22)	total: 3.29s	remaining: 1m 5s
# 24:	test: 0.8247197	best: 0.8247197 (24)	total: 3.41s	remaining: 1m 4s
# 25:	test: 0.8248560	best: 0.8248560 (25)	total: 3.55s	remaining: 1m 4s
# 26:	test: 0.8250839	best: 0.8250839 (26)	total: 3.69s	remaining: 1m 4s
# 27:	test: 0.8252827	best: 0.8252827 (27)	total: 3.84s	remaining: 1m 4s
# 28:	test: 0.8254947	best: 0.8254947 (28)	total: 3.97s	remaining: 1m 4s
# 29:	test: 0.8255997	best: 0.8255997 (29)	total: 4.1s	remaining: 1m 4s
# 30:	test: 0.8256666	best: 0.8256666 (30)	total: 4.22s	remaining: 1m 3s
# 31:	test: 0.8260297	best: 0.8260297 (31)	total: 4.36s	remaining: 1m 3s
# 32:	test: 0.8259551	best: 0.8260297 (31)	total: 4.49s	remaining: 1m 3s
# 33:	test: 0.8262076	best: 0.8262076 (33)	total: 4.63s	remaining: 1m 3s
# 34:	test: 0.8262933	best: 0.8262933 (34)	total: 4.77s	remaining: 1m 3s
# 35:	test: 0.8266752	best: 0.8266752 (35)	total: 4.91s	remaining: 1m 3s
# 36:	test: 0.8267553	best: 0.8267553 (36)	total: 5.04s	remaining: 1m 3s
# 37:	test: 0.8269349	best: 0.8269349 (37)	total: 5.17s	remaining: 1m 2s
# 38:	test: 0.8271000	best: 0.8271000 (38)	total: 5.31s	remaining: 1m 2s
# 39:	test: 0.8270844	best: 0.8271000 (38)	total: 5.45s	remaining: 1m 2s
# 40:	test: 0.8272891	best: 0.8272891 (40)	total: 5.59s	remaining: 1m 2s
# 41:	test: 0.8273941	best: 0.8273941 (41)	total: 5.72s	remaining: 1m 2s
# 42:	test: 0.8274915	best: 0.8274915 (42)	total: 5.86s	remaining: 1m 2s
# 43:	test: 0.8275332	best: 0.8275332 (43)	total: 6s	remaining: 1m 2s
# 44:	test: 0.8275760	best: 0.8275760 (44)	total: 6.14s	remaining: 1m 2s
# 45:	test: 0.8277259	best: 0.8277259 (45)	total: 6.28s	remaining: 1m 1s
# 46:	test: 0.8278100	best: 0.8278100 (46)	total: 6.42s	remaining: 1m 1s
# 47:	test: 0.8278998	best: 0.8278998 (47)	total: 6.56s	remaining: 1m 1s
# 48:	test: 0.8281759	best: 0.8281759 (48)	total: 6.69s	remaining: 1m 1s
# 49:	test: 0.8282096	best: 0.8282096 (49)	total: 6.83s	remaining: 1m 1s
# 50:	test: 0.8283446	best: 0.8283446 (50)	total: 6.96s	remaining: 1m 1s
# 51:	test: 0.8283927	best: 0.8283927 (51)	total: 7.1s	remaining: 1m 1s
# 52:	test: 0.8284833	best: 0.8284833 (52)	total: 7.24s	remaining: 1m 1s
# 53:	test: 0.8285258	best: 0.8285258 (53)	total: 7.36s	remaining: 1m
# 54:	test: 0.8285097	best: 0.8285258 (53)	total: 7.51s	remaining: 1m
# 55:	test: 0.8285522	best: 0.8285522 (55)	total: 7.65s	remaining: 1m
# 56:	test: 0.8285646	best: 0.8285646 (56)	total: 7.76s	remaining: 1m
# 57:	test: 0.8285987	best: 0.8285987 (57)	total: 7.9s	remaining: 1m
# 58:	test: 0.8286644	best: 0.8286644 (58)	total: 8.04s	remaining: 1m
# 59:	test: 0.8286828	best: 0.8286828 (59)	total: 8.14s	remaining: 59.7s
# 60:	test: 0.8288319	best: 0.8288319 (60)	total: 8.28s	remaining: 59.6s
# 61:	test: 0.8288375	best: 0.8288375 (61)	total: 8.42s	remaining: 59.5s
# 62:	test: 0.8287734	best: 0.8288375 (61)	total: 8.53s	remaining: 59.2s
# 63:	test: 0.8289377	best: 0.8289377 (63)	total: 8.65s	remaining: 58.9s
# 64:	test: 0.8289457	best: 0.8289457 (64)	total: 8.79s	remaining: 58.8s
# 65:	test: 0.8288547	best: 0.8289457 (64)	total: 8.91s	remaining: 58.6s
# 66:	test: 0.8289934	best: 0.8289934 (66)	total: 9.05s	remaining: 58.5s
# 67:	test: 0.8290968	best: 0.8290968 (67)	total: 9.19s	remaining: 58.4s
# 68:	test: 0.8290928	best: 0.8290968 (67)	total: 9.32s	remaining: 58.2s
# 69:	test: 0.8291897	best: 0.8291897 (69)	total: 9.45s	remaining: 58.1s
# 70:	test: 0.8292499	best: 0.8292499 (70)	total: 9.59s	remaining: 57.9s
# 71:	test: 0.8293989	best: 0.8293989 (71)	total: 9.73s	remaining: 57.9s
# 72:	test: 0.8295304	best: 0.8295304 (72)	total: 9.88s	remaining: 57.8s
# 73:	test: 0.8296421	best: 0.8296421 (73)	total: 10s	remaining: 57.6s
# 74:	test: 0.8297191	best: 0.8297191 (74)	total: 10.2s	remaining: 57.5s
# 75:	test: 0.8297608	best: 0.8297608 (75)	total: 10.3s	remaining: 57.3s
# 76:	test: 0.8298565	best: 0.8298565 (76)	total: 10.4s	remaining: 57.2s
# 77:	test: 0.8299599	best: 0.8299599 (77)	total: 10.5s	remaining: 57s
# 78:	test: 0.8300501	best: 0.8300501 (78)	total: 10.7s	remaining: 56.9s
# 79:	test: 0.8301675	best: 0.8301675 (79)	total: 10.8s	remaining: 56.8s
# 80:	test: 0.8302348	best: 0.8302348 (80)	total: 11s	remaining: 56.7s
# 81:	test: 0.8303005	best: 0.8303005 (81)	total: 11.1s	remaining: 56.5s
# 82:	test: 0.8303101	best: 0.8303101 (82)	total: 11.2s	remaining: 56.4s
# 83:	test: 0.8304096	best: 0.8304096 (83)	total: 11.4s	remaining: 56.3s
# 84:	test: 0.8304408	best: 0.8304408 (84)	total: 11.5s	remaining: 56.2s
# 85:	test: 0.8305041	best: 0.8305041 (85)	total: 11.6s	remaining: 55.9s
# 86:	test: 0.8305121	best: 0.8305121 (86)	total: 11.8s	remaining: 55.8s
# 87:	test: 0.8305345	best: 0.8305345 (87)	total: 11.9s	remaining: 55.7s
# 88:	test: 0.8306380	best: 0.8306380 (88)	total: 12s	remaining: 55.5s
# 89:	test: 0.8307485	best: 0.8307485 (89)	total: 12.2s	remaining: 55.5s
# 90:	test: 0.8308279	best: 0.8308279 (90)	total: 12.3s	remaining: 55.4s
# 91:	test: 0.8308896	best: 0.8308896 (91)	total: 12.4s	remaining: 55.2s
# 92:	test: 0.8309481	best: 0.8309481 (92)	total: 12.6s	remaining: 55.1s
# 93:	test: 0.8309938	best: 0.8309938 (93)	total: 12.7s	remaining: 54.9s
# 94:	test: 0.8310339	best: 0.8310339 (94)	total: 12.8s	remaining: 54.7s
# 95:	test: 0.8311116	best: 0.8311116 (95)	total: 13s	remaining: 54.6s
# 96:	test: 0.8311661	best: 0.8311661 (96)	total: 13.1s	remaining: 54.5s
# 97:	test: 0.8312655	best: 0.8312655 (97)	total: 13.3s	remaining: 54.4s
# 98:	test: 0.8313104	best: 0.8313104 (98)	total: 13.4s	remaining: 54.2s
# 99:	test: 0.8313448	best: 0.8313448 (99)	total: 13.5s	remaining: 54s
# 100:	test: 0.8314714	best: 0.8314714 (100)	total: 13.6s	remaining: 53.9s
# 101:	test: 0.8315508	best: 0.8315508 (101)	total: 13.8s	remaining: 53.8s
# 102:	test: 0.8316638	best: 0.8316638 (102)	total: 13.9s	remaining: 53.6s
# 103:	test: 0.8317239	best: 0.8317239 (103)	total: 14s	remaining: 53.5s
# 104:	test: 0.8317908	best: 0.8317908 (104)	total: 14.2s	remaining: 53.3s
# 105:	test: 0.8317700	best: 0.8317908 (104)	total: 14.3s	remaining: 53.3s
# 106:	test: 0.8317724	best: 0.8317908 (104)	total: 14.4s	remaining: 53s
# 107:	test: 0.8316866	best: 0.8317908 (104)	total: 14.6s	remaining: 52.8s
# 108:	test: 0.8316866	best: 0.8317908 (104)	total: 14.7s	remaining: 52.7s
# 109:	test: 0.8318597	best: 0.8318597 (109)	total: 14.8s	remaining: 52.5s
# 110:	test: 0.8318597	best: 0.8318597 (109)	total: 14.9s	remaining: 52.4s
# 111:	test: 0.8319435	best: 0.8319435 (111)	total: 15.1s	remaining: 52.2s
# 112:	test: 0.8320337	best: 0.8320337 (112)	total: 15.2s	remaining: 52s
# 113:	test: 0.8320168	best: 0.8320337 (112)	total: 15.3s	remaining: 51.9s
# 114:	test: 0.8320930	best: 0.8320930 (114)	total: 15.5s	remaining: 51.8s
# 115:	test: 0.8321840	best: 0.8321840 (115)	total: 15.6s	remaining: 51.6s
# 116:	test: 0.8321832	best: 0.8321840 (115)	total: 15.7s	remaining: 51.5s
# 117:	test: 0.8322128	best: 0.8322128 (117)	total: 15.9s	remaining: 51.4s
# 118:	test: 0.8322544	best: 0.8322544 (118)	total: 16s	remaining: 51.3s
# 119:	test: 0.8322200	best: 0.8322544 (118)	total: 16.1s	remaining: 51.1s
# 120:	test: 0.8322717	best: 0.8322717 (120)	total: 16.3s	remaining: 51s
# 121:	test: 0.8322725	best: 0.8322725 (121)	total: 16.4s	remaining: 50.8s
# 122:	test: 0.8322509	best: 0.8322725 (121)	total: 16.5s	remaining: 50.7s
# 123:	test: 0.8322509	best: 0.8322725 (121)	total: 16.7s	remaining: 50.5s
# 124:	test: 0.8323610	best: 0.8323610 (124)	total: 16.8s	remaining: 50.4s
# 125:	test: 0.8323923	best: 0.8323923 (125)	total: 16.9s	remaining: 50.3s
# 126:	test: 0.8324268	best: 0.8324268 (126)	total: 17.1s	remaining: 50.1s
# 127:	test: 0.8324692	best: 0.8324692 (127)	total: 17.2s	remaining: 50s
# 128:	test: 0.8325810	best: 0.8325810 (128)	total: 17.3s	remaining: 49.9s
# 129:	test: 0.8326420	best: 0.8326420 (129)	total: 17.5s	remaining: 49.7s
# 130:	test: 0.8326941	best: 0.8326941 (130)	total: 17.6s	remaining: 49.6s
# 131:	test: 0.8327333	best: 0.8327333 (131)	total: 17.8s	remaining: 49.5s
# 132:	test: 0.8327113	best: 0.8327333 (131)	total: 17.9s	remaining: 49.4s
# 133:	test: 0.8327381	best: 0.8327381 (133)	total: 18s	remaining: 49.2s
# 134:	test: 0.8327758	best: 0.8327758 (134)	total: 18.2s	remaining: 49.1s
# 135:	test: 0.8328359	best: 0.8328359 (135)	total: 18.3s	remaining: 48.9s
# 136:	test: 0.8328615	best: 0.8328615 (136)	total: 18.4s	remaining: 48.8s
# 137:	test: 0.8329433	best: 0.8329433 (137)	total: 18.6s	remaining: 48.7s
# 138:	test: 0.8329585	best: 0.8329585 (138)	total: 18.7s	remaining: 48.5s
# 139:	test: 0.8329569	best: 0.8329585 (138)	total: 18.8s	remaining: 48.4s
# 140:	test: 0.8330090	best: 0.8330090 (140)	total: 19s	remaining: 48.3s
# 141:	test: 0.8330375	best: 0.8330375 (141)	total: 19.1s	remaining: 48.1s
# 142:	test: 0.8330503	best: 0.8330503 (142)	total: 19.2s	remaining: 48s
# 143:	test: 0.8330739	best: 0.8330739 (143)	total: 19.4s	remaining: 47.9s
# 144:	test: 0.8331160	best: 0.8331160 (144)	total: 19.5s	remaining: 47.8s
# 145:	test: 0.8331400	best: 0.8331400 (145)	total: 19.6s	remaining: 47.6s
# 146:	test: 0.8332290	best: 0.8332290 (146)	total: 19.7s	remaining: 47.4s
# 147:	test: 0.8332354	best: 0.8332354 (147)	total: 19.9s	remaining: 47.3s
# 148:	test: 0.8333012	best: 0.8333012 (148)	total: 20s	remaining: 47.2s
# 149:	test: 0.8333508	best: 0.8333508 (149)	total: 20.2s	remaining: 47s
# 150:	test: 0.8333765	best: 0.8333765 (150)	total: 20.3s	remaining: 46.9s
# 151:	test: 0.8334735	best: 0.8334735 (151)	total: 20.4s	remaining: 46.8s
# 152:	test: 0.8335247	best: 0.8335247 (152)	total: 20.6s	remaining: 46.6s
# 153:	test: 0.8335319	best: 0.8335319 (153)	total: 20.7s	remaining: 46.5s
# 154:	test: 0.8336410	best: 0.8336410 (154)	total: 20.8s	remaining: 46.4s
# 155:	test: 0.8336714	best: 0.8336714 (155)	total: 21s	remaining: 46.3s
# 156:	test: 0.8336914	best: 0.8336914 (156)	total: 21.1s	remaining: 46.2s
# 157:	test: 0.8337419	best: 0.8337419 (157)	total: 21.3s	remaining: 46.1s
# 158:	test: 0.8337700	best: 0.8337700 (158)	total: 21.4s	remaining: 45.9s
# 159:	test: 0.8337980	best: 0.8337980 (159)	total: 21.6s	remaining: 45.8s
# 160:	test: 0.8337756	best: 0.8337980 (159)	total: 21.7s	remaining: 45.7s
# 161:	test: 0.8338004	best: 0.8338004 (161)	total: 21.8s	remaining: 45.6s
# 162:	test: 0.8338533	best: 0.8338533 (162)	total: 22s	remaining: 45.5s
# 163:	test: 0.8339351	best: 0.8339351 (163)	total: 22.1s	remaining: 45.3s
# 164:	test: 0.8339487	best: 0.8339487 (164)	total: 22.3s	remaining: 45.2s
# 165:	test: 0.8339455	best: 0.8339487 (164)	total: 22.4s	remaining: 45.1s
# 166:	test: 0.8340309	best: 0.8340309 (166)	total: 22.5s	remaining: 44.9s
# 167:	test: 0.8340457	best: 0.8340457 (167)	total: 22.7s	remaining: 44.8s
# 168:	test: 0.8340809	best: 0.8340809 (168)	total: 22.8s	remaining: 44.7s
# 169:	test: 0.8341739	best: 0.8341739 (169)	total: 22.9s	remaining: 44.5s
# 170:	test: 0.8342412	best: 0.8342412 (170)	total: 23.1s	remaining: 44.4s
# 171:	test: 0.8342549	best: 0.8342549 (171)	total: 23.2s	remaining: 44.3s
# 172:	test: 0.8343093	best: 0.8343093 (172)	total: 23.4s	remaining: 44.2s
# 173:	test: 0.8343943	best: 0.8343943 (173)	total: 23.5s	remaining: 44s
# 174:	test: 0.8344969	best: 0.8344969 (174)	total: 23.6s	remaining: 43.9s
# 175:	test: 0.8345666	best: 0.8345666 (175)	total: 23.8s	remaining: 43.8s
# 176:	test: 0.8345658	best: 0.8345666 (175)	total: 23.9s	remaining: 43.6s
# 177:	test: 0.8345867	best: 0.8345867 (177)	total: 24s	remaining: 43.4s
# 178:	test: 0.8346251	best: 0.8346251 (178)	total: 24.1s	remaining: 43.3s
# 179:	test: 0.8346636	best: 0.8346636 (179)	total: 24.3s	remaining: 43.1s
# 180:	test: 0.8347425	best: 0.8347425 (180)	total: 24.4s	remaining: 43s
# 181:	test: 0.8348147	best: 0.8348147 (181)	total: 24.6s	remaining: 42.9s
# 182:	test: 0.8348627	best: 0.8348627 (182)	total: 24.7s	remaining: 42.8s
# 183:	test: 0.8348844	best: 0.8348844 (183)	total: 24.8s	remaining: 42.7s
# 184:	test: 0.8349701	best: 0.8349701 (184)	total: 25s	remaining: 42.5s
# 185:	test: 0.8350367	best: 0.8350367 (185)	total: 25.1s	remaining: 42.4s
# 186:	test: 0.8351128	best: 0.8351128 (186)	total: 25.3s	remaining: 42.3s
# 187:	test: 0.8351441	best: 0.8351441 (187)	total: 25.4s	remaining: 42.1s
# 188:	test: 0.8351745	best: 0.8351745 (188)	total: 25.5s	remaining: 42s
# 189:	test: 0.8352114	best: 0.8352114 (189)	total: 25.6s	remaining: 41.8s
# 190:	test: 0.8352450	best: 0.8352450 (190)	total: 25.8s	remaining: 41.7s
# 191:	test: 0.8353043	best: 0.8353043 (191)	total: 25.9s	remaining: 41.6s
# 192:	test: 0.8353027	best: 0.8353043 (191)	total: 26.1s	remaining: 41.5s
# 193:	test: 0.8353220	best: 0.8353220 (193)	total: 26.2s	remaining: 41.4s
# 194:	test: 0.8353581	best: 0.8353581 (194)	total: 26.4s	remaining: 41.2s
# 195:	test: 0.8353885	best: 0.8353885 (195)	total: 26.5s	remaining: 41.1s
# 196:	test: 0.8354270	best: 0.8354270 (196)	total: 26.6s	remaining: 40.9s
# 197:	test: 0.8355063	best: 0.8355063 (197)	total: 26.8s	remaining: 40.8s
# 198:	test: 0.8355704	best: 0.8355704 (198)	total: 26.9s	remaining: 40.7s
# 199:	test: 0.8356425	best: 0.8356425 (199)	total: 27s	remaining: 40.5s
# 200:	test: 0.8356666	best: 0.8356666 (200)	total: 27.2s	remaining: 40.4s
# 201:	test: 0.8356995	best: 0.8356995 (201)	total: 27.3s	remaining: 40.3s
# 202:	test: 0.8357219	best: 0.8357219 (202)	total: 27.4s	remaining: 40.1s
# 203:	test: 0.8357444	best: 0.8357444 (203)	total: 27.6s	remaining: 40s
# 204:	test: 0.8358285	best: 0.8358285 (204)	total: 27.7s	remaining: 39.9s
# 205:	test: 0.8358541	best: 0.8358541 (205)	total: 27.8s	remaining: 39.7s
# 206:	test: 0.8358702	best: 0.8358702 (206)	total: 28s	remaining: 39.6s
# 207:	test: 0.8358870	best: 0.8358870 (207)	total: 28.1s	remaining: 39.5s
# 208:	test: 0.8359647	best: 0.8359647 (208)	total: 28.3s	remaining: 39.3s
# 209:	test: 0.8360120	best: 0.8360120 (209)	total: 28.4s	remaining: 39.2s
# 210:	test: 0.8360400	best: 0.8360400 (210)	total: 28.5s	remaining: 39.1s
# 211:	test: 0.8360946	best: 0.8360946 (211)	total: 28.7s	remaining: 39s
# 212:	test: 0.8361306	best: 0.8361306 (212)	total: 28.8s	remaining: 38.8s
# 213:	test: 0.8361851	best: 0.8361851 (213)	total: 29s	remaining: 38.7s
# 214:	test: 0.8362012	best: 0.8362012 (214)	total: 29.1s	remaining: 38.6s
# 215:	test: 0.8362084	best: 0.8362084 (215)	total: 29.2s	remaining: 38.5s
# 216:	test: 0.8362364	best: 0.8362364 (216)	total: 29.4s	remaining: 38.3s
# 217:	test: 0.8362252	best: 0.8362364 (216)	total: 29.5s	remaining: 38.2s
# 218:	test: 0.8362572	best: 0.8362572 (218)	total: 29.6s	remaining: 38s
# 219:	test: 0.8362781	best: 0.8362781 (219)	total: 29.8s	remaining: 37.9s
# 220:	test: 0.8363318	best: 0.8363318 (220)	total: 29.9s	remaining: 37.8s
# 221:	test: 0.8363510	best: 0.8363510 (221)	total: 30.1s	remaining: 37.6s
# 222:	test: 0.8364023	best: 0.8364023 (222)	total: 30.2s	remaining: 37.5s
# 223:	test: 0.8364072	best: 0.8364072 (223)	total: 30.3s	remaining: 37.4s
# 224:	test: 0.8364175	best: 0.8364175 (224)	total: 30.5s	remaining: 37.2s
# 225:	test: 0.8364680	best: 0.8364680 (225)	total: 30.6s	remaining: 37.1s
# 226:	test: 0.8365282	best: 0.8365282 (226)	total: 30.7s	remaining: 37s
# 227:	test: 0.8366083	best: 0.8366083 (227)	total: 30.9s	remaining: 36.8s
# 228:	test: 0.8366596	best: 0.8366596 (228)	total: 31s	remaining: 36.7s
# 229:	test: 0.8366844	best: 0.8366844 (229)	total: 31.1s	remaining: 36.5s
# 230:	test: 0.8367477	best: 0.8367477 (230)	total: 31.3s	remaining: 36.4s
# 231:	test: 0.8367910	best: 0.8367910 (231)	total: 31.4s	remaining: 36.2s
# 232:	test: 0.8367846	best: 0.8367910 (231)	total: 31.5s	remaining: 36.1s
# 233:	test: 0.8367966	best: 0.8367966 (233)	total: 31.6s	remaining: 35.9s
# 234:	test: 0.8368070	best: 0.8368070 (234)	total: 31.8s	remaining: 35.8s
# 235:	test: 0.8368223	best: 0.8368223 (235)	total: 31.9s	remaining: 35.7s
# 236:	test: 0.8368896	best: 0.8368896 (236)	total: 32s	remaining: 35.5s
# 237:	test: 0.8369441	best: 0.8369441 (237)	total: 32.1s	remaining: 35.4s
# 238:	test: 0.8369810	best: 0.8369810 (238)	total: 32.3s	remaining: 35.2s
# 239:	test: 0.8370354	best: 0.8370354 (239)	total: 32.4s	remaining: 35.1s
# 240:	test: 0.8370852	best: 0.8370852 (240)	total: 32.5s	remaining: 35s
# 241:	test: 0.8371112	best: 0.8371112 (241)	total: 32.7s	remaining: 34.8s
# 242:	test: 0.8371649	best: 0.8371649 (242)	total: 32.8s	remaining: 34.7s
# 243:	test: 0.8371897	best: 0.8371897 (243)	total: 32.9s	remaining: 34.6s
# 244:	test: 0.8372467	best: 0.8372467 (244)	total: 33.1s	remaining: 34.4s
# 245:	test: 0.8372755	best: 0.8372755 (245)	total: 33.2s	remaining: 34.2s
# 246:	test: 0.8373332	best: 0.8373332 (246)	total: 33.3s	remaining: 34.1s
# 247:	test: 0.8374318	best: 0.8374318 (247)	total: 33.4s	remaining: 33.9s
# 248:	test: 0.8374294	best: 0.8374318 (247)	total: 33.5s	remaining: 33.8s
# 249:	test: 0.8374462	best: 0.8374462 (249)	total: 33.7s	remaining: 33.7s
# 250:	test: 0.8374430	best: 0.8374462 (249)	total: 33.8s	remaining: 33.5s
# 251:	test: 0.8375119	best: 0.8375119 (251)	total: 33.9s	remaining: 33.4s
# 252:	test: 0.8375624	best: 0.8375624 (252)	total: 34.1s	remaining: 33.3s
# 253:	test: 0.8375860	best: 0.8375860 (253)	total: 34.2s	remaining: 33.1s
# 254:	test: 0.8376085	best: 0.8376085 (254)	total: 34.4s	remaining: 33s
# 255:	test: 0.8376318	best: 0.8376318 (255)	total: 34.5s	remaining: 32.9s
# 256:	test: 0.8376526	best: 0.8376526 (256)	total: 34.6s	remaining: 32.7s
# 257:	test: 0.8376983	best: 0.8376983 (257)	total: 34.7s	remaining: 32.6s
# 258:	test: 0.8376998	best: 0.8376998 (258)	total: 34.9s	remaining: 32.4s
# 259:	test: 0.8377199	best: 0.8377199 (259)	total: 35s	remaining: 32.3s
# 260:	test: 0.8377295	best: 0.8377295 (260)	total: 35.1s	remaining: 32.1s
# 261:	test: 0.8377544	best: 0.8377544 (261)	total: 35.2s	remaining: 32s
# 262:	test: 0.8377768	best: 0.8377768 (262)	total: 35.4s	remaining: 31.9s
# 263:	test: 0.8377824	best: 0.8377824 (263)	total: 35.5s	remaining: 31.7s
# 264:	test: 0.8378016	best: 0.8378016 (264)	total: 35.6s	remaining: 31.6s
# 265:	test: 0.8378457	best: 0.8378457 (265)	total: 35.8s	remaining: 31.5s
# 266:	test: 0.8378738	best: 0.8378738 (266)	total: 35.9s	remaining: 31.3s
# 267:	test: 0.8379323	best: 0.8379323 (267)	total: 36s	remaining: 31.2s
# 268:	test: 0.8379226	best: 0.8379323 (267)	total: 36.1s	remaining: 31s
# 269:	test: 0.8379475	best: 0.8379475 (269)	total: 36.3s	remaining: 30.9s
# 270:	test: 0.8379499	best: 0.8379499 (270)	total: 36.4s	remaining: 30.8s
# 271:	test: 0.8379627	best: 0.8379627 (271)	total: 36.6s	remaining: 30.6s
# 272:	test: 0.8379956	best: 0.8379956 (272)	total: 36.7s	remaining: 30.5s
# 273:	test: 0.8380405	best: 0.8380405 (273)	total: 36.8s	remaining: 30.4s
# 274:	test: 0.8380533	best: 0.8380533 (274)	total: 36.9s	remaining: 30.2s
# 275:	test: 0.8380533	best: 0.8380533 (274)	total: 37.1s	remaining: 30.1s
# 276:	test: 0.8380685	best: 0.8380685 (276)	total: 37.2s	remaining: 29.9s
# 277:	test: 0.8381398	best: 0.8381398 (277)	total: 37.3s	remaining: 29.8s
# 278:	test: 0.8381543	best: 0.8381543 (278)	total: 37.4s	remaining: 29.7s
# 279:	test: 0.8381912	best: 0.8381912 (279)	total: 37.6s	remaining: 29.5s
# 280:	test: 0.8381847	best: 0.8381912 (279)	total: 37.7s	remaining: 29.4s
# 281:	test: 0.8382016	best: 0.8382016 (281)	total: 37.8s	remaining: 29.3s
# 282:	test: 0.8382360	best: 0.8382360 (282)	total: 38s	remaining: 29.1s
# 283:	test: 0.8382609	best: 0.8382609 (283)	total: 38.1s	remaining: 29s
# 284:	test: 0.8382921	best: 0.8382921 (284)	total: 38.2s	remaining: 28.8s
# 285:	test: 0.8383298	best: 0.8383298 (285)	total: 38.3s	remaining: 28.7s
# 286:	test: 0.8383314	best: 0.8383314 (286)	total: 38.5s	remaining: 28.6s
# 287:	test: 0.8383330	best: 0.8383330 (287)	total: 38.6s	remaining: 28.4s
# 288:	test: 0.8383642	best: 0.8383642 (288)	total: 38.7s	remaining: 28.3s
# 289:	test: 0.8384059	best: 0.8384059 (289)	total: 38.9s	remaining: 28.1s
# 290:	test: 0.8384203	best: 0.8384203 (290)	total: 39s	remaining: 28s
# 291:	test: 0.8384396	best: 0.8384396 (291)	total: 39.1s	remaining: 27.9s
# 292:	test: 0.8384837	best: 0.8384837 (292)	total: 39.3s	remaining: 27.7s
# 293:	test: 0.8385029	best: 0.8385029 (293)	total: 39.4s	remaining: 27.6s
# 294:	test: 0.8385117	best: 0.8385117 (294)	total: 39.5s	remaining: 27.5s
# 295:	test: 0.8385205	best: 0.8385205 (295)	total: 39.6s	remaining: 27.3s
# 296:	test: 0.8385895	best: 0.8385895 (296)	total: 39.8s	remaining: 27.2s
# 297:	test: 0.8385967	best: 0.8385967 (297)	total: 39.9s	remaining: 27.1s
# 298:	test: 0.8386103	best: 0.8386103 (298)	total: 40.1s	remaining: 26.9s
# 299:	test: 0.8386247	best: 0.8386247 (299)	total: 40.2s	remaining: 26.8s
# 300:	test: 0.8386343	best: 0.8386343 (300)	total: 40.3s	remaining: 26.7s
# 301:	test: 0.8386784	best: 0.8386784 (301)	total: 40.5s	remaining: 26.5s
# 302:	test: 0.8387049	best: 0.8387049 (302)	total: 40.6s	remaining: 26.4s
# 303:	test: 0.8387281	best: 0.8387281 (303)	total: 40.8s	remaining: 26.3s
# 304:	test: 0.8387473	best: 0.8387473 (304)	total: 40.9s	remaining: 26.1s
# 305:	test: 0.8387746	best: 0.8387746 (305)	total: 41s	remaining: 26s
# 306:	test: 0.8387866	best: 0.8387866 (306)	total: 41.2s	remaining: 25.9s
# 307:	test: 0.8388387	best: 0.8388387 (307)	total: 41.3s	remaining: 25.7s
# 308:	test: 0.8388612	best: 0.8388612 (308)	total: 41.4s	remaining: 25.6s
# 309:	test: 0.8389012	best: 0.8389012 (309)	total: 41.6s	remaining: 25.5s
# 310:	test: 0.8389012	best: 0.8389012 (309)	total: 41.7s	remaining: 25.3s
# 311:	test: 0.8389173	best: 0.8389173 (311)	total: 41.8s	remaining: 25.2s
# 312:	test: 0.8389317	best: 0.8389317 (312)	total: 42s	remaining: 25.1s
# 313:	test: 0.8389301	best: 0.8389317 (312)	total: 42.1s	remaining: 25s
# 314:	test: 0.8389437	best: 0.8389437 (314)	total: 42.2s	remaining: 24.8s
# 315:	test: 0.8389541	best: 0.8389541 (315)	total: 42.4s	remaining: 24.7s
# 316:	test: 0.8390254	best: 0.8390254 (316)	total: 42.5s	remaining: 24.5s
# 317:	test: 0.8390471	best: 0.8390471 (317)	total: 42.6s	remaining: 24.4s
# 318:	test: 0.8390479	best: 0.8390479 (318)	total: 42.7s	remaining: 24.2s
# 319:	test: 0.8390343	best: 0.8390479 (318)	total: 42.8s	remaining: 24.1s
# 320:	test: 0.8390712	best: 0.8390712 (320)	total: 43s	remaining: 24s
# 321:	test: 0.8391136	best: 0.8391136 (321)	total: 43.1s	remaining: 23.8s
# 322:	test: 0.8391521	best: 0.8391521 (322)	total: 43.3s	remaining: 23.7s
# 323:	test: 0.8391561	best: 0.8391561 (323)	total: 43.4s	remaining: 23.6s
# 324:	test: 0.8391817	best: 0.8391817 (324)	total: 43.5s	remaining: 23.4s
# 325:	test: 0.8391970	best: 0.8391970 (325)	total: 43.7s	remaining: 23.3s
# 326:	test: 0.8392122	best: 0.8392122 (326)	total: 43.8s	remaining: 23.2s
# 327:	test: 0.8392347	best: 0.8392347 (327)	total: 43.9s	remaining: 23s
# 328:	test: 0.8392563	best: 0.8392563 (328)	total: 44s	remaining: 22.9s
# 329:	test: 0.8393031	best: 0.8393031 (329)	total: 44.2s	remaining: 22.8s
# 330:	test: 0.8393268	best: 0.8393268 (330)	total: 44.3s	remaining: 22.6s
# 331:	test: 0.8393388	best: 0.8393388 (331)	total: 44.5s	remaining: 22.5s
# 332:	test: 0.8393356	best: 0.8393388 (331)	total: 44.6s	remaining: 22.4s
# 333:	test: 0.8393517	best: 0.8393517 (333)	total: 44.7s	remaining: 22.2s
# 334:	test: 0.8393797	best: 0.8393797 (334)	total: 44.9s	remaining: 22.1s
# 335:	test: 0.8394085	best: 0.8394085 (335)	total: 45s	remaining: 22s
# 336:	test: 0.8394326	best: 0.8394326 (336)	total: 45.1s	remaining: 21.8s
# 337:	test: 0.8394734	best: 0.8394734 (337)	total: 45.2s	remaining: 21.7s
# 338:	test: 0.8395151	best: 0.8395151 (338)	total: 45.4s	remaining: 21.6s
# 339:	test: 0.8394863	best: 0.8395151 (338)	total: 45.5s	remaining: 21.4s
# 340:	test: 0.8395079	best: 0.8395151 (338)	total: 45.6s	remaining: 21.3s
# 341:	test: 0.8395143	best: 0.8395151 (338)	total: 45.8s	remaining: 21.1s
# 342:	test: 0.8395199	best: 0.8395199 (342)	total: 45.9s	remaining: 21s
# 343:	test: 0.8395560	best: 0.8395560 (343)	total: 46s	remaining: 20.9s
# 344:	test: 0.8395576	best: 0.8395576 (344)	total: 46.2s	remaining: 20.7s
# 345:	test: 0.8395920	best: 0.8395920 (345)	total: 46.3s	remaining: 20.6s
# 346:	test: 0.8396121	best: 0.8396121 (346)	total: 46.4s	remaining: 20.5s
# 347:	test: 0.8396385	best: 0.8396385 (347)	total: 46.6s	remaining: 20.3s
# 348:	test: 0.8396345	best: 0.8396385 (347)	total: 46.7s	remaining: 20.2s
# 349:	test: 0.8396410	best: 0.8396410 (349)	total: 46.8s	remaining: 20.1s
# 350:	test: 0.8396922	best: 0.8396922 (350)	total: 47s	remaining: 19.9s
# 351:	test: 0.8396987	best: 0.8396987 (351)	total: 47.1s	remaining: 19.8s
# 352:	test: 0.8397019	best: 0.8397019 (352)	total: 47.2s	remaining: 19.7s
# 353:	test: 0.8397195	best: 0.8397195 (353)	total: 47.4s	remaining: 19.5s
# 354:	test: 0.8397588	best: 0.8397588 (354)	total: 47.5s	remaining: 19.4s
# 355:	test: 0.8397932	best: 0.8397932 (355)	total: 47.6s	remaining: 19.3s
# 356:	test: 0.8398197	best: 0.8398197 (356)	total: 47.8s	remaining: 19.1s
# 357:	test: 0.8398437	best: 0.8398437 (357)	total: 47.9s	remaining: 19s
# 358:	test: 0.8398357	best: 0.8398437 (357)	total: 48s	remaining: 18.9s
# 359:	test: 0.8398557	best: 0.8398557 (359)	total: 48.2s	remaining: 18.7s
# 360:	test: 0.8398501	best: 0.8398557 (359)	total: 48.3s	remaining: 18.6s
# 361:	test: 0.8398974	best: 0.8398974 (361)	total: 48.4s	remaining: 18.5s
# 362:	test: 0.8398782	best: 0.8398974 (361)	total: 48.6s	remaining: 18.3s
# 363:	test: 0.8398790	best: 0.8398974 (361)	total: 48.7s	remaining: 18.2s
# 364:	test: 0.8398902	best: 0.8398974 (361)	total: 48.8s	remaining: 18.1s
# 365:	test: 0.8399118	best: 0.8399118 (365)	total: 48.9s	remaining: 17.9s
# 366:	test: 0.8399239	best: 0.8399239 (366)	total: 49.1s	remaining: 17.8s
# 367:	test: 0.8399415	best: 0.8399415 (367)	total: 49.2s	remaining: 17.6s
# 368:	test: 0.8399631	best: 0.8399631 (368)	total: 49.3s	remaining: 17.5s
# 369:	test: 0.8399864	best: 0.8399864 (369)	total: 49.5s	remaining: 17.4s
# 370:	test: 0.8399896	best: 0.8399896 (370)	total: 49.6s	remaining: 17.2s
# 371:	test: 0.8399936	best: 0.8399936 (371)	total: 49.8s	remaining: 17.1s
# 372:	test: 0.8400112	best: 0.8400112 (372)	total: 49.9s	remaining: 17s
# 373:	test: 0.8400048	best: 0.8400112 (372)	total: 50s	remaining: 16.8s
# 374:	test: 0.8400513	best: 0.8400513 (374)	total: 50.1s	remaining: 16.7s
# 375:	test: 0.8400729	best: 0.8400729 (375)	total: 50.3s	remaining: 16.6s
# 376:	test: 0.8400681	best: 0.8400729 (375)	total: 50.4s	remaining: 16.4s
# 377:	test: 0.8400745	best: 0.8400745 (377)	total: 50.5s	remaining: 16.3s
# 378:	test: 0.8401026	best: 0.8401026 (378)	total: 50.6s	remaining: 16.2s
# 379:	test: 0.8401186	best: 0.8401186 (379)	total: 50.8s	remaining: 16s
# 380:	test: 0.8401411	best: 0.8401411 (380)	total: 50.9s	remaining: 15.9s
# 381:	test: 0.8401763	best: 0.8401763 (381)	total: 51s	remaining: 15.8s
# 382:	test: 0.8401779	best: 0.8401779 (382)	total: 51.1s	remaining: 15.6s
# 383:	test: 0.8402180	best: 0.8402180 (383)	total: 51.3s	remaining: 15.5s
# 384:	test: 0.8402252	best: 0.8402252 (384)	total: 51.4s	remaining: 15.4s
# 385:	test: 0.8402557	best: 0.8402557 (385)	total: 51.5s	remaining: 15.2s
# 386:	test: 0.8403166	best: 0.8403166 (386)	total: 51.7s	remaining: 15.1s
# 387:	test: 0.8403118	best: 0.8403166 (386)	total: 51.8s	remaining: 15s
# 388:	test: 0.8403342	best: 0.8403342 (388)	total: 52s	remaining: 14.8s
# 389:	test: 0.8403471	best: 0.8403471 (389)	total: 52.1s	remaining: 14.7s
# 390:	test: 0.8403518	best: 0.8403518 (390)	total: 52.2s	remaining: 14.6s
# 391:	test: 0.8403727	best: 0.8403727 (391)	total: 52.4s	remaining: 14.4s
# 392:	test: 0.8403895	best: 0.8403895 (392)	total: 52.5s	remaining: 14.3s
# 393:	test: 0.8403951	best: 0.8403951 (393)	total: 52.6s	remaining: 14.2s
# 394:	test: 0.8404064	best: 0.8404064 (394)	total: 52.8s	remaining: 14s
# 395:	test: 0.8404328	best: 0.8404328 (395)	total: 52.9s	remaining: 13.9s
# 396:	test: 0.8404424	best: 0.8404424 (396)	total: 53s	remaining: 13.8s
# 397:	test: 0.8404416	best: 0.8404424 (396)	total: 53.1s	remaining: 13.6s
# 398:	test: 0.8404456	best: 0.8404456 (398)	total: 53.3s	remaining: 13.5s
# 399:	test: 0.8404688	best: 0.8404688 (399)	total: 53.4s	remaining: 13.4s
# 400:	test: 0.8404873	best: 0.8404873 (400)	total: 53.5s	remaining: 13.2s
# 401:	test: 0.8404929	best: 0.8404929 (401)	total: 53.7s	remaining: 13.1s
# 402:	test: 0.8405041	best: 0.8405041 (402)	total: 53.8s	remaining: 12.9s
# 403:	test: 0.8405025	best: 0.8405041 (402)	total: 53.9s	remaining: 12.8s
# 404:	test: 0.8404985	best: 0.8405041 (402)	total: 54.1s	remaining: 12.7s
# 405:	test: 0.8405218	best: 0.8405218 (405)	total: 54.2s	remaining: 12.5s
# 406:	test: 0.8405594	best: 0.8405594 (406)	total: 54.3s	remaining: 12.4s
# 407:	test: 0.8405610	best: 0.8405610 (407)	total: 54.4s	remaining: 12.3s
# 408:	test: 0.8405482	best: 0.8405610 (407)	total: 54.5s	remaining: 12.1s
# 409:	test: 0.8405546	best: 0.8405610 (407)	total: 54.7s	remaining: 12s
# 410:	test: 0.8405851	best: 0.8405851 (410)	total: 54.8s	remaining: 11.9s
# 411:	test: 0.8405867	best: 0.8405867 (411)	total: 54.9s	remaining: 11.7s
# 412:	test: 0.8406019	best: 0.8406019 (412)	total: 55s	remaining: 11.6s
# 413:	test: 0.8405979	best: 0.8406019 (412)	total: 55.2s	remaining: 11.5s
# 414:	test: 0.8406339	best: 0.8406339 (414)	total: 55.3s	remaining: 11.3s
# 415:	test: 0.8406636	best: 0.8406636 (415)	total: 55.4s	remaining: 11.2s
# 416:	test: 0.8406604	best: 0.8406636 (415)	total: 55.6s	remaining: 11.1s
# 417:	test: 0.8406588	best: 0.8406636 (415)	total: 55.7s	remaining: 10.9s
# 418:	test: 0.8406852	best: 0.8406852 (418)	total: 55.8s	remaining: 10.8s
# 419:	test: 0.8406844	best: 0.8406852 (418)	total: 56s	remaining: 10.7s
# 420:	test: 0.8406852	best: 0.8406852 (418)	total: 56s	remaining: 10.5s
# 421:	test: 0.8406925	best: 0.8406925 (421)	total: 56.2s	remaining: 10.4s
# 422:	test: 0.8407085	best: 0.8407085 (422)	total: 56.3s	remaining: 10.2s
# 423:	test: 0.8407013	best: 0.8407085 (422)	total: 56.4s	remaining: 10.1s
# 424:	test: 0.8407181	best: 0.8407181 (424)	total: 56.6s	remaining: 9.98s
# 425:	test: 0.8407205	best: 0.8407205 (425)	total: 56.7s	remaining: 9.85s
# 426:	test: 0.8407245	best: 0.8407245 (426)	total: 56.8s	remaining: 9.72s
# 427:	test: 0.8407409	best: 0.8407409 (427)	total: 56.9s	remaining: 9.58s
# 428:	test: 0.8407385	best: 0.8407409 (427)	total: 57.1s	remaining: 9.45s
# 429:	test: 0.8407201	best: 0.8407409 (427)	total: 57.2s	remaining: 9.31s
# 430:	test: 0.8407497	best: 0.8407497 (430)	total: 57.3s	remaining: 9.18s
# 431:	test: 0.8407670	best: 0.8407670 (431)	total: 57.4s	remaining: 9.04s
# 432:	test: 0.8407942	best: 0.8407942 (432)	total: 57.5s	remaining: 8.9s
# 433:	test: 0.8407830	best: 0.8407942 (432)	total: 57.7s	remaining: 8.77s
# 434:	test: 0.8407990	best: 0.8407990 (434)	total: 57.8s	remaining: 8.64s
# 435:	test: 0.8408311	best: 0.8408311 (435)	total: 57.9s	remaining: 8.5s
# 436:	test: 0.8408295	best: 0.8408311 (435)	total: 58.1s	remaining: 8.37s
# 437:	test: 0.8408672	best: 0.8408672 (437)	total: 58.2s	remaining: 8.24s
# 438:	test: 0.8408832	best: 0.8408832 (438)	total: 58.3s	remaining: 8.11s
# 439:	test: 0.8408880	best: 0.8408880 (439)	total: 58.5s	remaining: 7.97s
# 440:	test: 0.8409064	best: 0.8409064 (440)	total: 58.6s	remaining: 7.84s
# 441:	test: 0.8409305	best: 0.8409305 (441)	total: 58.7s	remaining: 7.7s
# 442:	test: 0.8409329	best: 0.8409329 (442)	total: 58.8s	remaining: 7.56s
# 443:	test: 0.8409465	best: 0.8409465 (443)	total: 58.9s	remaining: 7.43s
# 444:	test: 0.8409674	best: 0.8409674 (444)	total: 59s	remaining: 7.3s
# 445:	test: 0.8409802	best: 0.8409802 (445)	total: 59.2s	remaining: 7.16s
# 446:	test: 0.8409978	best: 0.8409978 (446)	total: 59.3s	remaining: 7.03s
# 447:	test: 0.8409930	best: 0.8409978 (446)	total: 59.4s	remaining: 6.9s
# 448:	test: 0.8410050	best: 0.8410050 (448)	total: 59.6s	remaining: 6.76s
# 449:	test: 0.8410355	best: 0.8410355 (449)	total: 59.7s	remaining: 6.63s
# 450:	test: 0.8410451	best: 0.8410451 (450)	total: 59.8s	remaining: 6.5s
# 451:	test: 0.8410475	best: 0.8410475 (451)	total: 59.9s	remaining: 6.36s
# 452:	test: 0.8410563	best: 0.8410563 (452)	total: 1m	remaining: 6.22s
# 453:	test: 0.8410363	best: 0.8410563 (452)	total: 1m	remaining: 6.09s
# 454:	test: 0.8410475	best: 0.8410563 (452)	total: 1m	remaining: 5.96s
# 455:	test: 0.8410411	best: 0.8410563 (452)	total: 1m	remaining: 5.82s
# 456:	test: 0.8410391	best: 0.8410563 (452)	total: 1m	remaining: 5.69s
# 457:	test: 0.8410932	best: 0.8410932 (457)	total: 1m	remaining: 5.55s
# 458:	test: 0.8410940	best: 0.8410940 (458)	total: 1m	remaining: 5.42s
# 459:	test: 0.8411124	best: 0.8411124 (459)	total: 1m	remaining: 5.29s
# 460:	test: 0.8411325	best: 0.8411325 (460)	total: 1m	remaining: 5.16s
# 461:	test: 0.8411541	best: 0.8411541 (461)	total: 1m 1s	remaining: 5.03s
# 462:	test: 0.8411605	best: 0.8411605 (462)	total: 1m 1s	remaining: 4.89s
# 463:	test: 0.8411765	best: 0.8411765 (463)	total: 1m 1s	remaining: 4.76s
# 464:	test: 0.8412222	best: 0.8412222 (464)	total: 1m 1s	remaining: 4.63s
# 465:	test: 0.8412206	best: 0.8412222 (464)	total: 1m 1s	remaining: 4.5s
# 466:	test: 0.8412102	best: 0.8412222 (464)	total: 1m 1s	remaining: 4.37s
# 467:	test: 0.8412535	best: 0.8412535 (467)	total: 1m 1s	remaining: 4.23s
# 468:	test: 0.8412446	best: 0.8412535 (467)	total: 1m 2s	remaining: 4.1s
# 469:	test: 0.8412526	best: 0.8412535 (467)	total: 1m 2s	remaining: 3.97s
# 470:	test: 0.8412446	best: 0.8412535 (467)	total: 1m 2s	remaining: 3.84s
# 471:	test: 0.8412607	best: 0.8412607 (471)	total: 1m 2s	remaining: 3.7s
# 472:	test: 0.8412783	best: 0.8412783 (472)	total: 1m 2s	remaining: 3.57s
# 473:	test: 0.8412911	best: 0.8412911 (473)	total: 1m 2s	remaining: 3.44s
# 474:	test: 0.8412919	best: 0.8412919 (474)	total: 1m 2s	remaining: 3.31s
# 475:	test: 0.8412935	best: 0.8412935 (475)	total: 1m 3s	remaining: 3.18s
# 476:	test: 0.8413160	best: 0.8413160 (476)	total: 1m 3s	remaining: 3.04s
# 477:	test: 0.8413056	best: 0.8413160 (476)	total: 1m 3s	remaining: 2.91s
# 478:	test: 0.8413240	best: 0.8413240 (478)	total: 1m 3s	remaining: 2.78s
# 479:	test: 0.8413176	best: 0.8413240 (478)	total: 1m 3s	remaining: 2.64s
# 480:	test: 0.8413160	best: 0.8413240 (478)	total: 1m 3s	remaining: 2.51s
# 481:	test: 0.8413537	best: 0.8413537 (481)	total: 1m 3s	remaining: 2.38s
# 482:	test: 0.8413584	best: 0.8413584 (482)	total: 1m 3s	remaining: 2.25s
# 483:	test: 0.8414029	best: 0.8414029 (483)	total: 1m 3s	remaining: 2.11s
# 484:	test: 0.8414053	best: 0.8414053 (484)	total: 1m 4s	remaining: 1.98s
# 485:	test: 0.8414081	best: 0.8414081 (485)	total: 1m 4s	remaining: 1.85s
# 486:	test: 0.8414202	best: 0.8414202 (486)	total: 1m 4s	remaining: 1.71s
# 487:	test: 0.8414418	best: 0.8414418 (487)	total: 1m 4s	remaining: 1.58s
# 488:	test: 0.8414394	best: 0.8414418 (487)	total: 1m 4s	remaining: 1.45s
# 489:	test: 0.8414595	best: 0.8414595 (489)	total: 1m 4s	remaining: 1.32s
# 490:	test: 0.8415155	best: 0.8415155 (490)	total: 1m 4s	remaining: 1.19s
# 491:	test: 0.8415251	best: 0.8415251 (491)	total: 1m 4s	remaining: 1.05s
# 492:	test: 0.8415251	best: 0.8415251 (491)	total: 1m 4s	remaining: 922ms
# 493:	test: 0.8415404	best: 0.8415404 (493)	total: 1m 5s	remaining: 790ms
# 494:	test: 0.8415275	best: 0.8415404 (493)	total: 1m 5s	remaining: 658ms
# 495:	test: 0.8415508	best: 0.8415508 (495)	total: 1m 5s	remaining: 526ms
# 496:	test: 0.8415556	best: 0.8415556 (496)	total: 1m 5s	remaining: 395ms
# 497:	test: 0.8415877	best: 0.8415877 (497)	total: 1m 5s	remaining: 263ms
# 498:	test: 0.8415917	best: 0.8415917 (498)	total: 1m 5s	remaining: 132ms
# 499:	test: 0.8416461	best: 0.8416461 (499)	total: 1m 5s	remaining: 0us
# bestTest = 0.8416461349
# bestIteration = 499
# VALID AUC : 0.8416461630935683 ACC : 0.7516778523489933
